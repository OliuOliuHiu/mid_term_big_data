# %% [markdown]
# Cấn Minh Hiếu -- K224161813
# Huỳnh Đức Hiếu -- K224161814
# Bùi Thị Huyền My -- K224161825
# Nguyễn Hồng Ngọc Mỹ -- K224161826
# Tiêu Đăng Vinh -- K224161842

# %% [markdown]
# Link source code: https://github.com/OliuOliuHiu/mid_term_big_data

# %% [markdown]
# Link demo: 15.135.56.134:8501
